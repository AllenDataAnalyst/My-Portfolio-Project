# %% [markdown]
# # DATA CLEANING IN SQL SERVER
# #### Data cleaning is an essential process in any data analysis project. This documentation outlines the steps taken to clean data in SQL queries for a portfolio project involving Nashville Housing data.

# %% [markdown]
# #### Here are the steps:<br>
#
# - Standardize the date format using the CONVERT function.<br>
# * Populate missing Property Address data by joining data from different tables and filling in the missing data.<br>
# - Break out the Property Address into individual columns, including Address, City, and State, using the SUBSTRING function.<br>
# * Break out the Owner Address into individual columns, including Address, City, and State, using the PARSENAME and REPLACE <br>functions.<br>
# - Change the "Sold as Vacant" field values from Y/N to Yes/No using the CASE function.<br>
# * Remove duplicates using the ROW_NUMBER function, and then delete duplicates.<br>
# - Remove the unused columns.
#
# <p style="text-align:center;">
#     <a href="https://github.com/AllenDataAnalyst/My-Portfolio-Project/tree/main/SQL/Data%20Cleaning">Click here to download SQL queries and Nashville Housing data</a>
# </p>

# %% [markdown]
# To check for the dataset, you can use the following SQL code: <br>
#
# SELECT *<br>
# FROM PorfolioProjectSQL.dbo.NashvilleHousing
#
# The output of the SQL query will be displayed below ↴↴↴

# %%
from IPython import display
display.Image("https://raw.githubusercontent.com/AllenDataAnalyst/AllenTheAnalyst.github.io/main/images/data%20cleaning/data.png")

# %% [markdown]
# ### After reviewing the data, I have identified some data quality issues that need to be addressed. Here are some of the issues we found:

# %% [markdown]
# #### 1. Standardize Date Format
# #### The first step in data cleaning is to ensure that the data is in a standardized format. This is particularly important when dealing with dates, which can be stored in different formats. The code uses the CONVERT function to standardize the SaleDate format and updates the NashvilleHousing table.

# %% [markdown]
# Standardize Date Format<br>
# code: <br>
#
#
# Select SaleDate, CONVERT(Date,SaleDate)<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>

# %% [markdown]
# ![data1.png](attachment:data1.png)

# %% [markdown]
# ###### Updating SaleDate Format:<br>
# code: <br>
# Update NashvilleHousing<br>
# SET SaleDate = CONVERT(Date,SaleDate)<br>
#
# #### If this code does not work as expected<br>
#
#
# alternative code:<br>
#
#
# ALTER TABLE NashvilleHousing<br>
# Add SaleDateConverted Date;<br>
#
# Update NashvilleHousing<br>
# SET SaleDateConverted = CONVERT(Date,SaleDate)<br>
#
# Select SaleDateConverted, CONVERT(Date,SaleDate)<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>
#
#
# ![data2.png](attachment:data2.png)

# %% [markdown]
# #### 2.Populate Property Address Data
# Retrieve all records in the NashvilleHousing table and order them by ParcelID <br>
# code:<br>
# Select *<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>
# order by ParcelID<br>

# %%
from IPython import display
display.Image("https://raw.githubusercontent.com/AllenDataAnalyst/AllenTheAnalyst.github.io/main/images/data%20cleaning/data3.png")

# %% [markdown]
# This SQL code retrieves the ParcelID and PropertyAddress columns from the NashvilleHousing table, and then joins the table with itself on the ParcelID column to find any duplicate entries with missing PropertyAddress values. The ISNULL function is used to return the non-null PropertyAddress value from either table, and the result is a table of ParcelIDs with their corresponding PropertyAddresses, where missing values have been filled in.<br>
# code:<br>
# Select a.ParcelID, a.PropertyAddress, b.ParcelID, b.PropertyAddress, ISNULL(a.PropertyAddress,b.PropertyAddress)<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing a<br>
# JOIN PorfolioProjectSQL.dbo.NashvilleHousing b<br>
# 	on a.ParcelID = b.ParcelID<br>
# 	AND a.[UniqueID ] <> b.[UniqueID ]<br>
# Where a.PropertyAddress is null<br>
#
#
# ![data4.png](attachment:data4.png)

# %% [markdown]
# ##### Updating data
# Update a <br>
# SET PropertyAddress = ISNULL(a.PropertyAddress,b.PropertyAddress)<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing a<br>
# JOIN PorfolioProjectSQL.dbo.NashvilleHousing b<br>
# 	on a.ParcelID = b.ParcelID<br>
# 	AND a.[UniqueID ] <> b.[UniqueID ]<br>
# Where a.PropertyAddress is null<br>

# %% [markdown]
# #### 3. Breaking out Address into Individual Columns (Address, City, State)
# The next step is to break down the PropertyAddress field into individual columns for Address, City, and State using the SUBSTRING function. The code then updates the NashvilleHousing table with the newly created columns.

# %% [markdown]
# code:
#
# Select PropertyAddress<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>
#
# ![data5.png](attachment:data5.png)

# %% [markdown]
# This code splits the PropertyAddress column in the NashvilleHousing table into Address and City columns.<br>
#
#
# SELECT<br>
# SUBSTRING(PropertyAddress, 1, CHARINDEX(',', PropertyAddress) -1 ) as Address<br>
# , SUBSTRING(PropertyAddress, CHARINDEX(',', PropertyAddress) + 1 , LEN(PropertyAddress)) as Address<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>
#
# ![data6.png](attachment:data6.png)

# %% [markdown]
# After checking the code, it ran as intended.<br>
#
# This SQL code adds two new columns to the table "NashvilleHousing" and __updates__ their values by splitting the existing <br><br>"PropertyAddress" column into two separate columns "PropertySplitAddress" and "PropertySplitCity<br>
#
# __code:__
#
# ALTER TABLE NashvilleHousing
# Add PropertySplitAddress Nvarchar(255);
#
# Update NashvilleHousing
# SET PropertySplitAddress = SUBSTRING(PropertyAddress, 1, CHARINDEX(',', PropertyAddress) -1 )
#
#
# ALTER TABLE NashvilleHousing
# Add PropertySplitCity Nvarchar(255);
#
# Update NashvilleHousing
# SET PropertySplitCity = SUBSTRING(PropertyAddress, CHARINDEX(',', PropertyAddress) + 1 , LEN(PropertyAddress))

# %%
import pypyodbc as podbc
import pandas as pd
conn2 = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=DESKTOP-D0VPHAK\SQLEXPRESS;"
                     "Database=PorfolioProjectSQL;"
                     "Trusted_Connection=yes;")

# running the SQL query i need
SQL_Query = pd.read_sql_query('''
Select *
From PorfolioProjectSQL.dbo.NashvilleHousing
''', conn2)

#conn.close()

# Viz
SQL_Query.head(40)
# Out:
#     uniqueid           parcelid                  landuse  \
# 0     21911.0  081 08 4C 008.00        RESIDENTIAL CONDO
# 1     18949.0  081 08 4D 001.00        RESIDENTIAL CONDO
# 2     15993.0  081 08 4D 002.00          VACANT RES LAND
# 3     20408.0  081 08 4E 001.00        RESIDENTIAL CONDO
# 4     20409.0  081 08 4E 002.00        RESIDENTIAL CONDO
# 5     25561.0  081 08 4F 001.00        RESIDENTIAL CONDO
# 6     25562.0  081 08 4F 002.00        RESIDENTIAL CONDO
# 7     35538.0  081 08 4G 001.00        RESIDENTIAL CONDO
# 8     33768.0  081 08 4G 002.00        RESIDENTIAL CONDO
# 9     33769.0  081 08 4I 001.00        RESIDENTIAL CONDO
# 10    31932.0  081 08 4I 002.00        RESIDENTIAL CONDO
# 11    20410.0  081 08 4J 001.00        RESIDENTIAL CONDO
# 12    30043.0  081 08 4J 001.00        RESIDENTIAL CONDO
# 13    20411.0  081 08 4J 002.00        RESIDENTIAL CONDO
# 14    30044.0  081 08 4J 002.00        RESIDENTIAL CONDO
# 15    24274.0  081 08 4K 001.00        RESIDENTIAL CONDO
# 16    27410.0  081 08 4K 001.00        RESIDENTIAL CONDO
# 17    45986.0  081 08 4K 001.00        RESIDENTIAL CONDO
# 18    24275.0  081 08 4K 002.00  VACANT RESIDENTIAL LAND
# 19    27411.0  081 08 4K 002.00  VACANT RESIDENTIAL LAND
# 20    45987.0  081 08 4K 002.00        RESIDENTIAL CONDO
# 21    42523.0  081 08 4N 002.00        RESIDENTIAL CONDO
# 22    49447.0  081 08 4O 001.00        RESIDENTIAL CONDO
# 23    55282.0  081 08 4O 002.00        RESIDENTIAL CONDO
# 24    55283.0  081 08 4P 002.00        RESIDENTIAL CONDO
# 25     7925.0   081 10 0 024.00            SINGLE FAMILY
# 26    41805.0   081 10 0 068.00            SINGLE FAMILY
# 27    36354.0   081 10 0 077.00            SINGLE FAMILY
# 28    24945.0   081 10 0 127.00            SINGLE FAMILY
# 29    54431.0   081 10 0 136.00            SINGLE FAMILY
# 30    29351.0   081 10 0 144.00            SINGLE FAMILY
# 31    21200.0   081 10 0 145.00            SINGLE FAMILY
# 32    32897.0   081 10 0 145.00            SINGLE FAMILY
# 33    28036.0   081 10 0 158.00  VACANT RESIDENTIAL LAND
# 34     7926.0   081 10 0 164.00            SINGLE FAMILY
# 35     9749.0   081 10 0 172.00            SINGLE FAMILY
# 36     8818.0   081 10 0 177.00            SINGLE FAMILY
# 37    24946.0   081 10 0 195.00                   DUPLEX
# 38    26097.0   081 10 0 206.00            SINGLE FAMILY
# 39    21201.0   081 10 0 209.00  VACANT RESIDENTIAL LAND
#
#                  propertyaddress   saledate  saleprice    legalreference  \
# 0    535  GARFIELD ST, NASHVILLE 2014-09-11   298900.0  20140924-0087547
# 1   1708 A  7TH AVE N, NASHVILLE 2014-07-14   372900.0  20140716-0063031
# 2   1708 B  7TH AVE N, NASHVILLE 2014-05-09   371600.0  20140516-0042293
# 3   1710 A  7TH AVE N, NASHVILLE 2014-08-26   395400.0  20140904-0081112
# 4   1710 B  7TH AVE N, NASHVILLE 2014-08-27   379900.0  20140905-0081617
# 5   1802 B  7TH AVE N, NASHVILLE 2014-12-22   449900.0  20150105-0000984
# 6   1802 A  7TH AVE N, NASHVILLE 2014-12-12   433900.0  20141218-0115801
# 7   1711 A  6TH AVE N, NASHVILLE 2015-07-30   440000.0  20150810-0079732
# 8   1711 B  6TH AVE N, NASHVILLE 2015-06-01   392940.0  20150604-0052123
# 9   1712 A  7TH AVE N, NASHVILLE 2015-06-19   455000.0  20150623-0060173
# 10  1712 B  7TH AVE N, NASHVILLE 2015-05-05   527590.0  20150520-0046543
# 11  1721 B  7TH AVE N, NASHVILLE 2014-08-13   220000.0  20140818-0074370
# 12  1721 B  7TH AVE N, NASHVILLE 2015-04-16   435000.0  20150417-0034551
# 13  1721 A  7TH AVE N, NASHVILLE 2014-08-13   220000.0  20140818-0074370
# 14  1721 A  7TH AVE N, NASHVILLE 2015-04-15   452900.0  20150421-0035438
# 15          7TH AVE N, NASHVILLE 2014-11-14   185500.0  20141118-0106028
# 16          7TH AVE N, NASHVILLE 2015-02-12   252000.0  20150219-0014548
# 17    1800  7TH AVE N, NASHVILLE 2016-03-16   597324.0  20160323-0027657
# 18          7TH AVE N, NASHVILLE 2014-11-14   185500.0  20141118-0106028
# 19          7TH AVE N, NASHVILLE 2015-02-12   252000.0  20150219-0014548
# 20   606  BUCHANAN ST, NASHVILLE 2016-03-18   569900.0  20160321-0026675
# 21  1715 B  6TH AVE N, NASHVILLE 2015-12-07   580000.0  20151211-0124795
# 22   1722 A7TH  AVE N, NASHVILLE 2016-05-19   455000.0  20160523-0051630
# 23   1722 B7TH  AVE N, NASHVILLE 2016-09-27   510000.0  20160930-0103546
# 24   1718 B6TH  AVE N, NASHVILLE 2016-09-20   539900.0  20160923-0100274
# 25   1721  26TH AVE N, NASHVILLE 2013-09-11    31000.0  20130913-0096604
# 26     2607  DELK AVE, NASHVILLE 2015-12-16    66000.0  20151221-0128174
# 27  2511  BUCHANAN ST, NASHVILLE 2015-08-06   192000.0  20150812-0080915
# 28     2514  DELK AVE, NASHVILLE 2014-12-08    63900.0  20141216-0115036
# 29     2519 DELK  AVE, NASHVILLE 2016-09-08   134000.0  20160909-0095246
# 30     2503  DELK AVE, NASHVILLE 2015-04-27    70350.0  20150505-0040891
# 31   1725  25TH AVE N, NASHVILLE 2014-09-29    58000.0  20141016-0095449
# 32   1725  25TH AVE N, NASHVILLE 2015-06-30   165000.0  20150702-0064275
# 33   2505  FINLAND ST, NASHVILLE 2015-03-16    26000.0  20150317-0022659
# 34     2506  OSAGE ST, NASHVILLE 2013-09-10    36500.0  20130913-0096747
# 35   1738  25TH AVE N, NASHVILLE 2013-11-25   102500.0  20131209-0124671
# 36   1728  25TH AVE N, NASHVILLE 2013-10-30    85500.0  20131031-0113261
# 37   1717  24TH AVE N, NASHVILLE 2014-12-19    62500.0  20141229-0118233
# 38    2401  SANTI AVE, NASHVILLE 2015-01-23    44107.0  20150126-0007322
# 39  2309  BUCHANAN ST, NASHVILLE 2014-09-10    36000.0  20140926-0088938
#
#    soldasvacant                                          ownername  \
# 0            No                                               None
# 1            No                                               None
# 2            No                                               None
# 3            No                                               None
# 4            No                                               None
# 5            No                                               None
# 6            No                                               None
# 7            No                                               None
# 8            No                                               None
# 9            No                                               None
# 10           No                                               None
# 11          Yes                                               None
# 12           No                                               None
# 13          Yes                                               None
# 14           No                                               None
# 15          Yes                                               None
# 16          Yes                                               None
# 17           No                                               None
# 18          Yes                                               None
# 19          Yes                                               None
# 20           No                                               None
# 21           No                                               None
# 22           No                                               None
# 23           No                                               None
# 24           No                                               None
# 25           No                    FAMILY VENTURES MANAGEMENT, LLC
# 26           No                         SEAL POINT PROPERTIES, LLC
# 27           No                                 KILPATRICK, AMY C.
# 28           No                               KREIGH, TAMARA MINER
# 29           No                                    PORT ROYAL, LLC
# 30           No                          CLAYBROOKS, NATHANIEL JR.
# 31           No                                AISEMBERG, PAULA A.
# 32           No                                AISEMBERG, PAULA A.
# 33            N  WEAVER, RYAN MICHAEL & BANKARD-WEAVER, SHELLEY A.
# 34           No                     FAMILY VENTURE MANAGEMENT, LLC
# 35           No                                 VRBA, ALEXANDRA E.
# 36           No                                HORTON, ZAINEB JEAN
# 37           No                                   HOLLAND, GREGORY
# 38           No                    WARD, RICHARD W. & ELIZABETH J.
# 39          Yes                                   DUKE BALLARD LLC
#
#                         owneraddress  acreage              taxdistrict  \
# 0                               None      NaN                     None
# 1                               None      NaN                     None
# 2                               None      NaN                     None
# 3                               None      NaN                     None
# 4                               None      NaN                     None
# 5                               None      NaN                     None
# 6                               None      NaN                     None
# 7                               None      NaN                     None
# 8                               None      NaN                     None
# 9                               None      NaN                     None
# 10                              None      NaN                     None
# 11                              None      NaN                     None
# 12                              None      NaN                     None
# 13                              None      NaN                     None
# 14                              None      NaN                     None
# 15                              None      NaN                     None
# 16                              None      NaN                     None
# 17                              None      NaN                     None
# 18                              None      NaN                     None
# 19                              None      NaN                     None
# 20                              None      NaN                     None
# 21                              None      NaN                     None
# 22                              None      NaN                     None
# 23                              None      NaN                     None
# 24                              None      NaN                     None
# 25   1721  26TH AVE N, NASHVILLE, TN     0.12  URBAN SERVICES DISTRICT
# 26     2607  DELK AVE, NASHVILLE, TN     0.18  URBAN SERVICES DISTRICT
# 27  2511  BUCHANAN ST, NASHVILLE, TN     0.26  URBAN SERVICES DISTRICT
# 28     2514  DELK AVE, NASHVILLE, TN     0.17  URBAN SERVICES DISTRICT
# 29     2519  DELK AVE, NASHVILLE, TN     0.30  URBAN SERVICES DISTRICT
# 30     2503  DELK AVE, NASHVILLE, TN     0.21  URBAN SERVICES DISTRICT
# 31   1725  25TH AVE N, NASHVILLE, TN     0.23  URBAN SERVICES DISTRICT
# 32   1725  25TH AVE N, NASHVILLE, TN     0.23  URBAN SERVICES DISTRICT
# 33   2505  FINLAND ST, NASHVILLE, TN     0.16  URBAN SERVICES DISTRICT
# 34     2506  OSAGE ST, NASHVILLE, TN     0.17  URBAN SERVICES DISTRICT
# 35   1738  25TH AVE N, NASHVILLE, TN     0.17  URBAN SERVICES DISTRICT
# 36   1728  25TH AVE N, NASHVILLE, TN     0.17  URBAN SERVICES DISTRICT
# 37   1717  24TH AVE N, NASHVILLE, TN     0.18  URBAN SERVICES DISTRICT
# 38    2401  SANTI AVE, NASHVILLE, TN     0.09  URBAN SERVICES DISTRICT
# 39  2309  BUCHANAN ST, NASHVILLE, TN     0.17  URBAN SERVICES DISTRICT
#
#     landvalue  buildingvalue  totalvalue  yearbuilt  bedrooms  fullbath  \
# 0         NaN            NaN         NaN        NaN       NaN       NaN
# 1         NaN            NaN         NaN        NaN       NaN       NaN
# 2         NaN            NaN         NaN        NaN       NaN       NaN
# 3         NaN            NaN         NaN        NaN       NaN       NaN
# 4         NaN            NaN         NaN        NaN       NaN       NaN
# 5         NaN            NaN         NaN        NaN       NaN       NaN
# 6         NaN            NaN         NaN        NaN       NaN       NaN
# 7         NaN            NaN         NaN        NaN       NaN       NaN
# 8         NaN            NaN         NaN        NaN       NaN       NaN
# 9         NaN            NaN         NaN        NaN       NaN       NaN
# 10        NaN            NaN         NaN        NaN       NaN       NaN
# 11        NaN            NaN         NaN        NaN       NaN       NaN
# 12        NaN            NaN         NaN        NaN       NaN       NaN
# 13        NaN            NaN         NaN        NaN       NaN       NaN
# 14        NaN            NaN         NaN        NaN       NaN       NaN
# 15        NaN            NaN         NaN        NaN       NaN       NaN
# 16        NaN            NaN         NaN        NaN       NaN       NaN
# 17        NaN            NaN         NaN        NaN       NaN       NaN
# 18        NaN            NaN         NaN        NaN       NaN       NaN
# 19        NaN            NaN         NaN        NaN       NaN       NaN
# 20        NaN            NaN         NaN        NaN       NaN       NaN
# 21        NaN            NaN         NaN        NaN       NaN       NaN
# 22        NaN            NaN         NaN        NaN       NaN       NaN
# 23        NaN            NaN         NaN        NaN       NaN       NaN
# 24        NaN            NaN         NaN        NaN       NaN       NaN
# 25    11000.0        39500.0     50500.0     1962.0       3.0       1.0
# 26    11000.0        37000.0     48000.0     1955.0       2.0       2.0
# 27    13000.0       151900.0    165500.0     1930.0       4.0       1.0
# 28    13000.0        48700.0     61700.0     1940.0       2.0       1.0
# 29    13000.0        71200.0     84200.0     1999.0       3.0       2.0
# 30    13000.0        63000.0     76000.0     1930.0       4.0       2.0
# 31    13000.0        89500.0    102500.0     1984.0       3.0       2.0
# 32    13000.0        89500.0    102500.0     1984.0       3.0       2.0
# 33    13000.0            0.0     13000.0        NaN       NaN       NaN
# 34    13000.0        45600.0     58600.0     1931.0       2.0       1.0
# 35    13000.0        74300.0     87300.0     2006.0       3.0       2.0
# 36    13000.0        50900.0     63900.0     1963.0       3.0       1.0
# 37    13000.0        43000.0     56000.0     1965.0       2.0       2.0
# 38    13000.0        50400.0     63400.0     1940.0       2.0       1.0
# 39    13000.0            0.0     13000.0        NaN       NaN       NaN
#
#     halfbath saledateconverted propertysplitaddress propertysplitcity
# 0        NaN        2014-09-11     535  GARFIELD ST         NASHVILLE
# 1        NaN        2014-07-14    1708 A  7TH AVE N         NASHVILLE
# 2        NaN        2014-05-09    1708 B  7TH AVE N         NASHVILLE
# 3        NaN        2014-08-26    1710 A  7TH AVE N         NASHVILLE
# 4        NaN        2014-08-27    1710 B  7TH AVE N         NASHVILLE
# 5        NaN        2014-12-22    1802 B  7TH AVE N         NASHVILLE
# 6        NaN        2014-12-12    1802 A  7TH AVE N         NASHVILLE
# 7        NaN        2015-07-30    1711 A  6TH AVE N         NASHVILLE
# 8        NaN        2015-06-01    1711 B  6TH AVE N         NASHVILLE
# 9        NaN        2015-06-19    1712 A  7TH AVE N         NASHVILLE
# 10       NaN        2015-05-05    1712 B  7TH AVE N         NASHVILLE
# 11       NaN        2014-08-13    1721 B  7TH AVE N         NASHVILLE
# 12       NaN        2015-04-16    1721 B  7TH AVE N         NASHVILLE
# 13       NaN        2014-08-13    1721 A  7TH AVE N         NASHVILLE
# 14       NaN        2015-04-15    1721 A  7TH AVE N         NASHVILLE
# 15       NaN        2014-11-14            7TH AVE N         NASHVILLE
# 16       NaN        2015-02-12            7TH AVE N         NASHVILLE
# 17       NaN        2016-03-16      1800  7TH AVE N         NASHVILLE
# 18       NaN        2014-11-14            7TH AVE N         NASHVILLE
# 19       NaN        2015-02-12            7TH AVE N         NASHVILLE
# 20       NaN        2016-03-18     606  BUCHANAN ST         NASHVILLE
# 21       NaN        2015-12-07    1715 B  6TH AVE N         NASHVILLE
# 22       NaN        2016-05-19     1722 A7TH  AVE N         NASHVILLE
# 23       NaN        2016-09-27     1722 B7TH  AVE N         NASHVILLE
# 24       NaN        2016-09-20     1718 B6TH  AVE N         NASHVILLE
# 25       0.0        2013-09-11     1721  26TH AVE N         NASHVILLE
# 26       0.0        2015-12-16       2607  DELK AVE         NASHVILLE
# 27       1.0        2015-08-06    2511  BUCHANAN ST         NASHVILLE
# 28       0.0        2014-12-08       2514  DELK AVE         NASHVILLE
# 29       0.0        2016-09-08       2519 DELK  AVE         NASHVILLE
# 30       0.0        2015-04-27       2503  DELK AVE         NASHVILLE
# 31       0.0        2014-09-29     1725  25TH AVE N         NASHVILLE
# 32       0.0        2015-06-30     1725  25TH AVE N         NASHVILLE
# 33       NaN        2015-03-16     2505  FINLAND ST         NASHVILLE
# 34       0.0        2013-09-10       2506  OSAGE ST         NASHVILLE
# 35       0.0        2013-11-25     1738  25TH AVE N         NASHVILLE
# 36       0.0        2013-10-30     1728  25TH AVE N         NASHVILLE
# 37       0.0        2014-12-19     1717  24TH AVE N         NASHVILLE
# 38       0.0        2015-01-23      2401  SANTI AVE         NASHVILLE
# 39       NaN        2014-09-10    2309  BUCHANAN ST         NASHVILLE

# %% [markdown]
# Now, we can __split the OwnerAddress column__ using the __PARSENAME__ function. Instead of using SUBSTRING, CHARINDEX, and LEN, we can use a more concise code by utilizing the PARSENAME function.

# %%
# running the SQL query i need
SQL_Query = pd.read_sql_query('''Select OwnerAddress
From PorfolioProjectSQL.dbo.NashvilleHousing where owneraddress is not null''', conn2)



# Viz
SQL_Query.head(10)
# Out:
#                        owneraddress
# 0   1721  26TH AVE N, NASHVILLE, TN
# 1     2607  DELK AVE, NASHVILLE, TN
# 2  2511  BUCHANAN ST, NASHVILLE, TN
# 3     2514  DELK AVE, NASHVILLE, TN
# 4     2519  DELK AVE, NASHVILLE, TN
# 5     2503  DELK AVE, NASHVILLE, TN
# 6   1725  25TH AVE N, NASHVILLE, TN
# 7   1725  25TH AVE N, NASHVILLE, TN
# 8   2505  FINLAND ST, NASHVILLE, TN
# 9     2506  OSAGE ST, NASHVILLE, TN

# %% [markdown]
# __code:__ <br>
# Select<br>
# PARSENAME(REPLACE(OwnerAddress, ',', '.') , 3)<br>
# ,PARSENAME(REPLACE(OwnerAddress, ',', '.') , 2)<br>
# ,PARSENAME(REPLACE(OwnerAddress, ',', '.') , 1)<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>

# %%
import pypyodbc as podbc
import pandas as pd
conn2 = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=DESKTOP-D0VPHAK\SQLEXPRESS;"
                     "Database=PorfolioProjectSQL;"
                     "Trusted_Connection=yes;")

# running the SQL query i need
SQL_Query = pd.read_sql_query('''Select
PARSENAME(REPLACE(OwnerAddress, ',', '.') , 3)
,PARSENAME(REPLACE(OwnerAddress, ',', '.') , 2)
,PARSENAME(REPLACE(OwnerAddress, ',', '.') , 1)
From PorfolioProjectSQL.dbo.NashvilleHousing
where OwnerAddress is not null''', conn2)



# Viz
SQL_Query.head(10)
# Out:
#
# 0   1721  26TH AVE N   NASHVILLE   TN
# 1     2607  DELK AVE   NASHVILLE   TN
# 2  2511  BUCHANAN ST   NASHVILLE   TN
# 3     2514  DELK AVE   NASHVILLE   TN
# 4     2519  DELK AVE   NASHVILLE   TN
# 5     2503  DELK AVE   NASHVILLE   TN
# 6   1725  25TH AVE N   NASHVILLE   TN
# 7   1725  25TH AVE N   NASHVILLE   TN
# 8   2505  FINLAND ST   NASHVILLE   TN
# 9     2506  OSAGE ST   NASHVILLE   TN

# %% [markdown]
# Since the code works as intended, we can now update our table <br>
#
# __code:__<br>
# ALTER TABLE NashvilleHousing<br>
# Add OwnerSplitAddress Nvarchar(255);<br>
#
# Update NashvilleHousing<br>
# SET OwnerSplitAddress = PARSENAME(REPLACE(OwnerAddress, ',', '.') , 3)<br>
#
#
# ALTER TABLE NashvilleHousing<br>
# Add OwnerSplitCity Nvarchar(255);<br>
#
# Update NashvilleHousing
# SET OwnerSplitCity = PARSENAME(REPLACE(OwnerAddress, ',', '.') , 2)<br>
#
#
#
# ALTER TABLE NashvilleHousing<br>
# Add OwnerSplitState Nvarchar(255);<br>
#
# Update NashvilleHousing<br>
# SET OwnerSplitState = PARSENAME(REPLACE(OwnerAddress, ',', '.') , 1)<br>

# %%
import pypyodbc as podbc

# Create a connection to the SQL Server database
conn = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=DESKTOP-D0VPHAK\SQLEXPRESS;"
                     "Database=PorfolioProjectSQL;"
                     "Trusted_Connection=yes;")

# Define the SQL queries to alter the table
alter_query_1 = '''ALTER TABLE NashvilleHousing ADD OwnerSplitAddress NVARCHAR(255);'''
alter_query_2 = '''UPDATE NashvilleHousing SET OwnerSplitAddress = PARSENAME(REPLACE(OwnerAddress, ',', '.') , 3);'''
alter_query_3 = '''ALTER TABLE NashvilleHousing ADD OwnerSplitCity NVARCHAR(255);'''
alter_query_4 = '''UPDATE NashvilleHousing SET OwnerSplitCity = PARSENAME(REPLACE(OwnerAddress, ',', '.') , 2);'''
alter_query_5 = '''ALTER TABLE NashvilleHousing ADD OwnerSplitState NVARCHAR(255);'''
alter_query_6 = '''UPDATE NashvilleHousing SET OwnerSplitState = PARSENAME(REPLACE(OwnerAddress, ',', '.') , 1);'''

# Execute the SQL queries
cursor = conn.cursor()
cursor.execute(alter_query_1)
cursor.execute(alter_query_2)
cursor.execute(alter_query_3)
cursor.execute(alter_query_4)
cursor.execute(alter_query_5)
cursor.execute(alter_query_6)

# Commit the changes and close the connection
conn.commit()
conn.close()

# %%
# running the SQL query i need
SQL_Query = pd.read_sql_query('''Select *
From PorfolioProjectSQL.dbo.NashvilleHousing
where owneraddress is not null''', conn2)



# Viz
SQL_Query.head(10)
# Out:
#    uniqueid          parcelid                  landuse  \
# 0     7925.0  081 10 0 024.00            SINGLE FAMILY
# 1    41805.0  081 10 0 068.00            SINGLE FAMILY
# 2    36354.0  081 10 0 077.00            SINGLE FAMILY
# 3    24945.0  081 10 0 127.00            SINGLE FAMILY
# 4    54431.0  081 10 0 136.00            SINGLE FAMILY
# 5    29351.0  081 10 0 144.00            SINGLE FAMILY
# 6    21200.0  081 10 0 145.00            SINGLE FAMILY
# 7    32897.0  081 10 0 145.00            SINGLE FAMILY
# 8    28036.0  081 10 0 158.00  VACANT RESIDENTIAL LAND
# 9     7926.0  081 10 0 164.00            SINGLE FAMILY
#
#                 propertyaddress   saledate  saleprice    legalreference  \
# 0   1721  26TH AVE N, NASHVILLE 2013-09-11    31000.0  20130913-0096604
# 1     2607  DELK AVE, NASHVILLE 2015-12-16    66000.0  20151221-0128174
# 2  2511  BUCHANAN ST, NASHVILLE 2015-08-06   192000.0  20150812-0080915
# 3     2514  DELK AVE, NASHVILLE 2014-12-08    63900.0  20141216-0115036
# 4     2519 DELK  AVE, NASHVILLE 2016-09-08   134000.0  20160909-0095246
# 5     2503  DELK AVE, NASHVILLE 2015-04-27    70350.0  20150505-0040891
# 6   1725  25TH AVE N, NASHVILLE 2014-09-29    58000.0  20141016-0095449
# 7   1725  25TH AVE N, NASHVILLE 2015-06-30   165000.0  20150702-0064275
# 8   2505  FINLAND ST, NASHVILLE 2015-03-16    26000.0  20150317-0022659
# 9     2506  OSAGE ST, NASHVILLE 2013-09-10    36500.0  20130913-0096747
#
#   soldasvacant                                          ownername  \
# 0           No                    FAMILY VENTURES MANAGEMENT, LLC
# 1           No                         SEAL POINT PROPERTIES, LLC
# 2           No                                 KILPATRICK, AMY C.
# 3           No                               KREIGH, TAMARA MINER
# 4           No                                    PORT ROYAL, LLC
# 5           No                          CLAYBROOKS, NATHANIEL JR.
# 6           No                                AISEMBERG, PAULA A.
# 7           No                                AISEMBERG, PAULA A.
# 8            N  WEAVER, RYAN MICHAEL & BANKARD-WEAVER, SHELLEY A.
# 9           No                     FAMILY VENTURE MANAGEMENT, LLC
#
#                        owneraddress  acreage              taxdistrict  \
# 0   1721  26TH AVE N, NASHVILLE, TN     0.12  URBAN SERVICES DISTRICT
# 1     2607  DELK AVE, NASHVILLE, TN     0.18  URBAN SERVICES DISTRICT
# 2  2511  BUCHANAN ST, NASHVILLE, TN     0.26  URBAN SERVICES DISTRICT
# 3     2514  DELK AVE, NASHVILLE, TN     0.17  URBAN SERVICES DISTRICT
# 4     2519  DELK AVE, NASHVILLE, TN     0.30  URBAN SERVICES DISTRICT
# 5     2503  DELK AVE, NASHVILLE, TN     0.21  URBAN SERVICES DISTRICT
# 6   1725  25TH AVE N, NASHVILLE, TN     0.23  URBAN SERVICES DISTRICT
# 7   1725  25TH AVE N, NASHVILLE, TN     0.23  URBAN SERVICES DISTRICT
# 8   2505  FINLAND ST, NASHVILLE, TN     0.16  URBAN SERVICES DISTRICT
# 9     2506  OSAGE ST, NASHVILLE, TN     0.17  URBAN SERVICES DISTRICT
#
#    landvalue  buildingvalue  totalvalue  yearbuilt  bedrooms  fullbath  \
# 0    11000.0        39500.0     50500.0     1962.0       3.0       1.0
# 1    11000.0        37000.0     48000.0     1955.0       2.0       2.0
# 2    13000.0       151900.0    165500.0     1930.0       4.0       1.0
# 3    13000.0        48700.0     61700.0     1940.0       2.0       1.0
# 4    13000.0        71200.0     84200.0     1999.0       3.0       2.0
# 5    13000.0        63000.0     76000.0     1930.0       4.0       2.0
# 6    13000.0        89500.0    102500.0     1984.0       3.0       2.0
# 7    13000.0        89500.0    102500.0     1984.0       3.0       2.0
# 8    13000.0            0.0     13000.0        NaN       NaN       NaN
# 9    13000.0        45600.0     58600.0     1931.0       2.0       1.0
#
#    halfbath saledateconverted propertysplitaddress propertysplitcity  \
# 0       0.0        2013-09-11     1721  26TH AVE N         NASHVILLE
# 1       0.0        2015-12-16       2607  DELK AVE         NASHVILLE
# 2       1.0        2015-08-06    2511  BUCHANAN ST         NASHVILLE
# 3       0.0        2014-12-08       2514  DELK AVE         NASHVILLE
# 4       0.0        2016-09-08       2519 DELK  AVE         NASHVILLE
# 5       0.0        2015-04-27       2503  DELK AVE         NASHVILLE
# 6       0.0        2014-09-29     1725  25TH AVE N         NASHVILLE
# 7       0.0        2015-06-30     1725  25TH AVE N         NASHVILLE
# 8       NaN        2015-03-16     2505  FINLAND ST         NASHVILLE
# 9       0.0        2013-09-10       2506  OSAGE ST         NASHVILLE
#
#    ownersplitaddress ownersplitcity ownersplitstate
# 0   1721  26TH AVE N      NASHVILLE              TN
# 1     2607  DELK AVE      NASHVILLE              TN
# 2  2511  BUCHANAN ST      NASHVILLE              TN
# 3     2514  DELK AVE      NASHVILLE              TN
# 4     2519  DELK AVE      NASHVILLE              TN
# 5     2503  DELK AVE      NASHVILLE              TN
# 6   1725  25TH AVE N      NASHVILLE              TN
# 7   1725  25TH AVE N      NASHVILLE              TN
# 8   2505  FINLAND ST      NASHVILLE              TN
# 9     2506  OSAGE ST      NASHVILLE              TN

# %% [markdown]
# #### 4. Change the "Sold as Vacant" field values from Y/N to Yes/No using the CASE function.

# %% [markdown]
# Count the number of properties sold as vacant <br>
# __code:__ <br>
# Select Distinct(SoldAsVacant), Count(SoldAsVacant)<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>
# Group by SoldAsVacant<br>
# order by 2<br>

# %%
# running the SQL query i need
SQL_Query = pd.read_sql_query('''Select Distinct(SoldAsVacant), Count(SoldAsVacant)
From PorfolioProjectSQL.dbo.NashvilleHousing
Group by SoldAsVacant
order by 2''', conn2)



# Viz
SQL_Query.head(10)
# Out:
#   soldasvacant
# 0            Y     52
# 1            N    399
# 2          Yes   4623
# 3           No  51403

# %% [markdown]
# Display a column for SoldAsVacant with 'Yes' or 'No' instead of 'Y' or 'N' <br>
#
# __code:__<br>
# Select SoldAsVacant<br>
# , CASE When SoldAsVacant = 'Y' THEN 'Yes'<br>
# When SoldAsVacant = 'N' THEN 'No'<br>
# ELSE SoldAsVacant<br>
# END<br>
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>

# %%
# running the SQL query i need
SQL_Query = pd.read_sql_query('''Select SoldAsVacant
, CASE When SoldAsVacant = 'Y' THEN 'Yes'
When SoldAsVacant = 'N' THEN 'No'
ELSE SoldAsVacant
END
From PorfolioProjectSQL.dbo.NashvilleHousing''', conn2)



# Viz
SQL_Query.head(10)
# Out:
#   soldasvacant
# 0           No  No
# 1           No  No
# 2           No  No
# 3           No  No
# 4           No  No
# 5           No  No
# 6           No  No
# 7           No  No
# 8           No  No
# 9           No  No

# %% [markdown]
# Since the code works as intended, we can now update our table <br>
# __code:__<br>
# Update NashvilleHousing<br>
# SET SoldAsVacant = CASE When SoldAsVacant = 'Y' THEN 'Yes'<br>
# 	   When SoldAsVacant = 'N' THEN 'No'<br>
# 	   ELSE SoldAsVa<br>
# 	   END<br>

# %%
import pypyodbc as podbc

# Create a connection to the SQL Server database
conn = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=DESKTOP-D0VPHAK\SQLEXPRESS;"
                     "Database=PorfolioProjectSQL;"
                     "Trusted_Connection=yes;")

update_query = '''UPDATE NashvilleHousing
SET SoldAsVacant = CASE
WHEN SoldAsVacant = 'Y' THEN 'Yes'
WHEN SoldAsVacant = 'N' THEN 'No'
ELSE SoldAsVacant
END;'''

#Execute the SQL query
cursor = conn.cursor()
cursor.execute(update_query)

#Commit the changes and close the connection
conn.commit()

# %% [markdown]
# Checking if the update was successful

# %%
# running the SQL query i need
SQL_Query = pd.read_sql_query('''Select Distinct(SoldAsVacant), Count(SoldAsVacant)
From PorfolioProjectSQL.dbo.NashvilleHousing
Group by SoldAsVacant
order by 2''', conn2)



# Viz
SQL_Query.head(10)
# Out:
#   soldasvacant
# 0          Yes   4675
# 1           No  51802

# %% [markdown]
# ##### 5. Remove duplicates using the ROW_NUMBER function, and then delete duplicates

# %% [markdown]
# We need to check if there are duplicates by using row_number. If the resulting row_num is greater than or equal to 2, then we have duplicates.<br>
#
# <br>
# WITH RowNumCTE AS(<br>
# Select *,<br>
# 	ROW_NUMBER() OVER (<br>
# 	PARTITION BY ParcelID,<br>
# 				 PropertyAddress,<br>
# 				 SalePrice,<br>
# 				 SaleDate,<br>
# 				 LegalReference<br>
# 				 ORDER BY<br>
# 					UniqueID<br>
# 					) row_num<br>
#
# From PorfolioProjectSQL.dbo.NashvilleHousing<br>
# --order by ParcelID<br>
# )
# Select *<br>
# From RowNumCTE<br>
# Where row_num > 1<br>
# Order by PropertyAddress<br>

# %%
SQL_Query = pd.read_sql_query('''WITH RowNumCTE AS(
Select *,ROW_NUMBER() OVER (PARTITION BY ParcelID,PropertyAddress,
 SalePrice,
 LegalReference
 ORDER BY
UniqueID
) row_num

From PorfolioProjectSQL.dbo.NashvilleHousing
--order by ParcelID
)
Select *
From RowNumCTE
Where row_num > 1
Order by PropertyAddress
''', conn)

# Viz
SQL_Query.head(10)
# Out:
#    uniqueid           parcelid            landuse  \
# 0    27354.0   107 14 0 157.00      SINGLE FAMILY
# 1    27383.0   150 04 0 144.00      SINGLE FAMILY
# 2    27362.0   119 16 0 084.00             DUPLEX
# 3    27132.0   091 08 0 056.00      SINGLE FAMILY
# 4    27368.0  135 10 0E 020.00  RESIDENTIAL CONDO
# 5    27369.0  135 10 0E 021.00  RESIDENTIAL CONDO
# 6    27123.0   091 04 0 046.00      SINGLE FAMILY
# 7    38363.0   053 03 0 278.00      SINGLE FAMILY
# 8    25581.0   081 16 0 250.00      SINGLE FAMILY
# 9    27351.0  098 09 0B 009.00      SINGLE FAMILY
#
#                      propertyaddress   saledate  saleprice    legalreference  \
# 0       1003  BRILEY PKWY, NASHVILLE 2015-02-12    80000.0  20150219-0014347
# 1      1005  ESTURBRIDGE CT, ANTIOCH 2015-02-13   180000.0  20150213-0013547
# 2       1006  DRUMMOND DR, NASHVILLE 2015-02-17    80000.0  20150218-0014086
# 3        1011  43RD AVE N, NASHVILLE 2015-02-23    69900.0  20150227-0017102
# 4  1023  CAPITAL FUNDS CT, NASHVILLE 2015-02-06   118981.0  20150210-0012380
# 5  1025  CAPITAL FUNDS CT, NASHVILLE 2015-02-06   118981.0  20150210-0012389
# 6        1038  40TH AVE N, NASHVILLE 2015-02-23    40000.0  20150227-0016978
# 7         104  HURST DR, OLD HICKORY 2015-09-24   160000.0  20150604-0052245
# 8       1042 B  SCOVEL ST, NASHVILLE 2014-12-18   140000.0  20141223-0117247
# 9      108  WINDCHASE RUN, HERMITAGE 2015-02-18   210000.0  20150225-0016199
#
#   soldasvacant                       ownername  \
# 0           No                GREEN, KASSANDRA
# 1           No                     TINNEY, STU
# 2           No                     POST, KEVIN
# 3           No            MENDING HEARTS, INC.
# 4           No                            None
# 5           No                            None
# 6           No              DAVIS, CRYSTAL ANN
# 7           No  SMITH, NATHAN W. & JENNIFER L.
# 8          Yes            JDG INVESTMENTS, LLC
# 9           No                            None
#
#                         owneraddress  acreage                taxdistrict  \
# 0   1003  BRILEY PKWY, NASHVILLE, TN     0.22    URBAN SERVICES DISTRICT
# 1  1005  ESTURBRIDGE CT, ANTIOCH, TN     0.31    URBAN SERVICES DISTRICT
# 2   1006  DRUMMOND DR, NASHVILLE, TN     0.99    URBAN SERVICES DISTRICT
# 3    1011  43RD AVE N, NASHVILLE, TN     0.17    URBAN SERVICES DISTRICT
# 4                               None      NaN                       None
# 5                               None      NaN                       None
# 6    1038  40TH AVE N, NASHVILLE, TN     0.14    URBAN SERVICES DISTRICT
# 7     104  HURST DR, OLD HICKORY, TN     0.40  GENERAL SERVICES DISTRICT
# 8    1042 B SCOVEL ST, NASHVILLE, TN     0.21    URBAN SERVICES DISTRICT
# 9                               None      NaN                       None
#
#    landvalue  buildingvalue  totalvalue  yearbuilt  bedrooms  fullbath  \
# 0    17000.0        64600.0     81600.0     1949.0       2.0       2.0
# 1    29500.0       131600.0    161100.0     1987.0       4.0       3.0
# 2    14300.0        87500.0    101800.0     1958.0       4.0       3.0
# 3    20000.0        41600.0     61600.0     1940.0       3.0       2.0
# 4        NaN            NaN         NaN        NaN       NaN       NaN
# 5        NaN            NaN         NaN        NaN       NaN       NaN
# 6    20000.0        83000.0    103000.0     1947.0       3.0       1.0
# 7    26000.0       100500.0    126500.0     1960.0       3.0       1.0
# 8    40000.0            0.0     40000.0        NaN       NaN       NaN
# 9        NaN            NaN         NaN        NaN       NaN       NaN
#
#    halfbath saledateconverted    propertysplitaddress propertysplitcity  \
# 0       0.0        2015-02-12       1003  BRILEY PKWY         NASHVILLE
# 1       0.0        2015-02-13    1005  ESTURBRIDGE CT           ANTIOCH
# 2       0.0        2015-02-17       1006  DRUMMOND DR         NASHVILLE
# 3       0.0        2015-02-23        1011  43RD AVE N         NASHVILLE
# 4       NaN        2015-02-06  1023  CAPITAL FUNDS CT         NASHVILLE
# 5       NaN        2015-02-06  1025  CAPITAL FUNDS CT         NASHVILLE
# 6       0.0        2015-02-23        1038  40TH AVE N         NASHVILLE
# 7       1.0        2015-09-24           104  HURST DR       OLD HICKORY
# 8       NaN        2014-12-18       1042 B  SCOVEL ST         NASHVILLE
# 9       NaN        2015-02-18      108  WINDCHASE RUN         HERMITAGE
#
#       ownersplitaddress ownersplitcity ownersplitstate  row_num
# 0     1003  BRILEY PKWY      NASHVILLE              TN        2
# 1  1005  ESTURBRIDGE CT        ANTIOCH              TN        2
# 2     1006  DRUMMOND DR      NASHVILLE              TN        2
# 3      1011  43RD AVE N      NASHVILLE              TN        2
# 4                  None           None            None        2
# 5                  None           None            None        2
# 6      1038  40TH AVE N      NASHVILLE              TN        2
# 7         104  HURST DR    OLD HICKORY              TN        2
# 8      1042 B SCOVEL ST      NASHVILLE              TN        2
# 9                  None           None            None        2

# %%
import pyodbc

# Create a connection to the SQL Server database
conn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=DESKTOP-D0VPHAK\\SQLEXPRESS;"
                      "Database=PorfolioProjectSQL;"
                      "Trusted_Connection=yes;")

# Define the SQL query
sql_query = '''WITH RowNumCTE AS(
                SELECT *,
                    ROW_NUMBER() OVER (
                        PARTITION BY ParcelID,
                                     PropertyAddress,
                                     SalePrice,
                                     SaleDate,
                                     LegalReference
                                     ORDER BY
                                     UniqueID
                                     ) row_num
                FROM PorfolioProjectSQL.dbo.NashvilleHousing
                --order by ParcelID
            )
            DELETE
            FROM RowNumCTE
            WHERE row_num > 1'''

# Execute the SQL query
cursor = conn.cursor()
cursor.execute(sql_query)

# Commit the changes and close the connection
conn.commit()

# %% [markdown]
# Checking if the update was successful

# %%
import pypyodbc as podbc
import pandas as pd

# Create a connection to the SQL Server database
conn = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=DESKTOP-D0VPHAK\SQLEXPRESS;"
                     "Database=PorfolioProjectSQL;"
                     "Trusted_Connection=yes;")

# Define the SQL query
SQL_Query = '''
WITH RowNumCTE AS(
Select *,
	ROW_NUMBER() OVER (
	PARTITION BY ParcelID,
				 PropertyAddress,
				 SalePrice,
				 SaleDate,
				 LegalReference
				 ORDER BY
					UniqueID
					) row_num
From PorfolioProjectSQL.dbo.NashvilleHousing
--order by ParcelID
)
Select *
From RowNumCTE
Where row_num > 1
Order by PropertyAddress
'''

# Execute the SQL query and read the result set into a Pandas DataFrame
df = pd.read_sql_query(SQL_Query, conn)

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# Empty DataFrame
# Columns: [uniqueid , parcelid, landuse, propertyaddress, saledate, saleprice, legalreference, soldasvacant, ownername, owneraddress, acreage, taxdistrict, landvalue, buildingvalue, totalvalue, yearbuilt, bedrooms, fullbath, halfbath, saledateconverted, propertysplitaddress, propertysplitcity, ownersplitaddress, ownersplitcity, ownersplitstate, row_num]
# Index: []

# %% [markdown]
# ##### We successfully remove duplicates

# %% [markdown]
# ##### 6. Delete Unused Columns

# %%
SQL_Query = pd.read_sql_query('''Select *
From PorfolioProjectSQL.dbo.NashvilleHousing''', conn)

# Viz
SQL_Query.head(10)
# Out:
#    uniqueid           parcelid            landuse  \
# 0    21911.0  081 08 4C 008.00  RESIDENTIAL CONDO
# 1    18949.0  081 08 4D 001.00  RESIDENTIAL CONDO
# 2    15993.0  081 08 4D 002.00    VACANT RES LAND
# 3    20408.0  081 08 4E 001.00  RESIDENTIAL CONDO
# 4    20409.0  081 08 4E 002.00  RESIDENTIAL CONDO
# 5    25561.0  081 08 4F 001.00  RESIDENTIAL CONDO
# 6    25562.0  081 08 4F 002.00  RESIDENTIAL CONDO
# 7    35538.0  081 08 4G 001.00  RESIDENTIAL CONDO
# 8    33768.0  081 08 4G 002.00  RESIDENTIAL CONDO
# 9    33769.0  081 08 4I 001.00  RESIDENTIAL CONDO
#
#                 propertyaddress   saledate  saleprice    legalreference  \
# 0   535  GARFIELD ST, NASHVILLE 2014-09-11   298900.0  20140924-0087547
# 1  1708 A  7TH AVE N, NASHVILLE 2014-07-14   372900.0  20140716-0063031
# 2  1708 B  7TH AVE N, NASHVILLE 2014-05-09   371600.0  20140516-0042293
# 3  1710 A  7TH AVE N, NASHVILLE 2014-08-26   395400.0  20140904-0081112
# 4  1710 B  7TH AVE N, NASHVILLE 2014-08-27   379900.0  20140905-0081617
# 5  1802 B  7TH AVE N, NASHVILLE 2014-12-22   449900.0  20150105-0000984
# 6  1802 A  7TH AVE N, NASHVILLE 2014-12-12   433900.0  20141218-0115801
# 7  1711 A  6TH AVE N, NASHVILLE 2015-07-30   440000.0  20150810-0079732
# 8  1711 B  6TH AVE N, NASHVILLE 2015-06-01   392940.0  20150604-0052123
# 9  1712 A  7TH AVE N, NASHVILLE 2015-06-19   455000.0  20150623-0060173
#
#   soldasvacant ownername owneraddress  acreage taxdistrict  landvalue  \
# 0           No      None         None      NaN        None        NaN
# 1           No      None         None      NaN        None        NaN
# 2           No      None         None      NaN        None        NaN
# 3           No      None         None      NaN        None        NaN
# 4           No      None         None      NaN        None        NaN
# 5           No      None         None      NaN        None        NaN
# 6           No      None         None      NaN        None        NaN
# 7           No      None         None      NaN        None        NaN
# 8           No      None         None      NaN        None        NaN
# 9           No      None         None      NaN        None        NaN
#
#    buildingvalue  totalvalue  yearbuilt  bedrooms  fullbath  halfbath  \
# 0            NaN         NaN        NaN       NaN       NaN       NaN
# 1            NaN         NaN        NaN       NaN       NaN       NaN
# 2            NaN         NaN        NaN       NaN       NaN       NaN
# 3            NaN         NaN        NaN       NaN       NaN       NaN
# 4            NaN         NaN        NaN       NaN       NaN       NaN
# 5            NaN         NaN        NaN       NaN       NaN       NaN
# 6            NaN         NaN        NaN       NaN       NaN       NaN
# 7            NaN         NaN        NaN       NaN       NaN       NaN
# 8            NaN         NaN        NaN       NaN       NaN       NaN
# 9            NaN         NaN        NaN       NaN       NaN       NaN
#
#   saledateconverted propertysplitaddress propertysplitcity ownersplitaddress  \
# 0        2014-09-11     535  GARFIELD ST         NASHVILLE              None
# 1        2014-07-14    1708 A  7TH AVE N         NASHVILLE              None
# 2        2014-05-09    1708 B  7TH AVE N         NASHVILLE              None
# 3        2014-08-26    1710 A  7TH AVE N         NASHVILLE              None
# 4        2014-08-27    1710 B  7TH AVE N         NASHVILLE              None
# 5        2014-12-22    1802 B  7TH AVE N         NASHVILLE              None
# 6        2014-12-12    1802 A  7TH AVE N         NASHVILLE              None
# 7        2015-07-30    1711 A  6TH AVE N         NASHVILLE              None
# 8        2015-06-01    1711 B  6TH AVE N         NASHVILLE              None
# 9        2015-06-19    1712 A  7TH AVE N         NASHVILLE              None
#
#   ownersplitcity ownersplitstate
# 0           None            None
# 1           None            None
# 2           None            None
# 3           None            None
# 4           None            None
# 5           None            None
# 6           None            None
# 7           None            None
# 8           None            None
# 9           None            None

# %%
import pypyodbc as podbc

# Create a connection to the SQL Server database
conn = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=DESKTOP-D0VPHAK\SQLEXPRESS;"
                     "Database=PorfolioProjectSQL;"
                     "Trusted_Connection=yes;")

# Define the SQL query to alter the table
alter_query = '''ALTER TABLE PorfolioProjectSQL.dbo.NashvilleHousing
                 DROP COLUMN OwnerAddress, TaxDistrict, PropertyAddress, SaleDate'''

# Execute the SQL query
cursor = conn.cursor()
cursor.execute(alter_query)

# Commit the changes and close the connection
conn.commit()

# %%
import pypyodbc as podbc

# Create a connection to the SQL Server database
conn = podbc.connect("Driver={SQL Server Native Client 11.0};"
                     "Server=DESKTOP-D0VPHAK\SQLEXPRESS;"
                     "Database=PorfolioProjectSQL;"
                     "Trusted_Connection=yes;")

SQL_Query = pd.read_sql_query('''Select *
From PorfolioProjectSQL.dbo.NashvilleHousing''', conn)
# Close the connection
conn.close()

# Viz
SQL_Query.head(50)
# Out:
#     uniqueid           parcelid                  landuse  saleprice  \
# 0     21911.0  081 08 4C 008.00        RESIDENTIAL CONDO   298900.0
# 1     18949.0  081 08 4D 001.00        RESIDENTIAL CONDO   372900.0
# 2     15993.0  081 08 4D 002.00          VACANT RES LAND   371600.0
# 3     20408.0  081 08 4E 001.00        RESIDENTIAL CONDO   395400.0
# 4     20409.0  081 08 4E 002.00        RESIDENTIAL CONDO   379900.0
# 5     25561.0  081 08 4F 001.00        RESIDENTIAL CONDO   449900.0
# 6     25562.0  081 08 4F 002.00        RESIDENTIAL CONDO   433900.0
# 7     35538.0  081 08 4G 001.00        RESIDENTIAL CONDO   440000.0
# 8     33768.0  081 08 4G 002.00        RESIDENTIAL CONDO   392940.0
# 9     33769.0  081 08 4I 001.00        RESIDENTIAL CONDO   455000.0
# 10    31932.0  081 08 4I 002.00        RESIDENTIAL CONDO   527590.0
# 11    20410.0  081 08 4J 001.00        RESIDENTIAL CONDO   220000.0
# 12    30043.0  081 08 4J 001.00        RESIDENTIAL CONDO   435000.0
# 13    20411.0  081 08 4J 002.00        RESIDENTIAL CONDO   220000.0
# 14    30044.0  081 08 4J 002.00        RESIDENTIAL CONDO   452900.0
# 15    24274.0  081 08 4K 001.00        RESIDENTIAL CONDO   185500.0
# 16    27410.0  081 08 4K 001.00        RESIDENTIAL CONDO   252000.0
# 17    45986.0  081 08 4K 001.00        RESIDENTIAL CONDO   597324.0
# 18    24275.0  081 08 4K 002.00  VACANT RESIDENTIAL LAND   185500.0
# 19    27411.0  081 08 4K 002.00  VACANT RESIDENTIAL LAND   252000.0
# 20    45987.0  081 08 4K 002.00        RESIDENTIAL CONDO   569900.0
# 21    42523.0  081 08 4N 002.00        RESIDENTIAL CONDO   580000.0
# 22    49447.0  081 08 4O 001.00        RESIDENTIAL CONDO   455000.0
# 23    55282.0  081 08 4O 002.00        RESIDENTIAL CONDO   510000.0
# 24    55283.0  081 08 4P 002.00        RESIDENTIAL CONDO   539900.0
# 25     7925.0   081 10 0 024.00            SINGLE FAMILY    31000.0
# 26    41805.0   081 10 0 068.00            SINGLE FAMILY    66000.0
# 27    36354.0   081 10 0 077.00            SINGLE FAMILY   192000.0
# 28    24945.0   081 10 0 127.00            SINGLE FAMILY    63900.0
# 29    54431.0   081 10 0 136.00            SINGLE FAMILY   134000.0
# 30    29351.0   081 10 0 144.00            SINGLE FAMILY    70350.0
# 31    21200.0   081 10 0 145.00            SINGLE FAMILY    58000.0
# 32    32897.0   081 10 0 145.00            SINGLE FAMILY   165000.0
# 33    28036.0   081 10 0 158.00  VACANT RESIDENTIAL LAND    26000.0
# 34     7926.0   081 10 0 164.00            SINGLE FAMILY    36500.0
# 35     9749.0   081 10 0 172.00            SINGLE FAMILY   102500.0
# 36     8818.0   081 10 0 177.00            SINGLE FAMILY    85500.0
# 37    24946.0   081 10 0 195.00                   DUPLEX    62500.0
# 38    26097.0   081 10 0 206.00            SINGLE FAMILY    44107.0
# 39    21201.0   081 10 0 209.00  VACANT RESIDENTIAL LAND    36000.0
# 40    46722.0   081 10 0 209.00  VACANT RESIDENTIAL LAND    80000.0
# 41    18259.0   081 10 0 212.00  VACANT RESIDENTIAL LAND    11000.0
# 42    12344.0   081 10 0 213.00            SINGLE FAMILY    67000.0
# 43    43983.0   081 10 0 213.00            SINGLE FAMILY   155000.0
# 44    30931.0   081 10 0 219.00            SINGLE FAMILY    40000.0
# 45    55904.0   081 10 0 221.00            SINGLE FAMILY   130000.0
# 46    26098.0   081 10 0 224.00            SINGLE FAMILY    56000.0
# 47    22592.0   081 10 0 225.00            SINGLE FAMILY   129000.0
# 48    42976.0   081 10 0 226.00            SINGLE FAMILY    77500.0
# 49    48533.0   081 10 0 226.00            SINGLE FAMILY   161000.0
#
#       legalreference soldasvacant  \
# 0   20140924-0087547           No
# 1   20140716-0063031           No
# 2   20140516-0042293           No
# 3   20140904-0081112           No
# 4   20140905-0081617           No
# 5   20150105-0000984           No
# 6   20141218-0115801           No
# 7   20150810-0079732           No
# 8   20150604-0052123           No
# 9   20150623-0060173           No
# 10  20150520-0046543           No
# 11  20140818-0074370          Yes
# 12  20150417-0034551           No
# 13  20140818-0074370          Yes
# 14  20150421-0035438           No
# 15  20141118-0106028          Yes
# 16  20150219-0014548          Yes
# 17  20160323-0027657           No
# 18  20141118-0106028          Yes
# 19  20150219-0014548          Yes
# 20  20160321-0026675           No
# 21  20151211-0124795           No
# 22  20160523-0051630           No
# 23  20160930-0103546           No
# 24  20160923-0100274           No
# 25  20130913-0096604           No
# 26  20151221-0128174           No
# 27  20150812-0080915           No
# 28  20141216-0115036           No
# 29  20160909-0095246           No
# 30  20150505-0040891           No
# 31  20141016-0095449           No
# 32  20150702-0064275           No
# 33  20150317-0022659           No
# 34  20130913-0096747           No
# 35  20131209-0124671           No
# 36  20131031-0113261           No
# 37  20141229-0118233           No
# 38  20150126-0007322           No
# 39  20140926-0088938          Yes
# 40  20160505-0044691           No
# 41  20140728-0066914          Yes
# 42  20140303-0017644           No
# 43  20160222-0016728           No
# 44  20150513-0044133           No
# 45  20161101-0115193           No
# 46  20150116-0004558           No
# 47  20141017-0095941           No
# 48  20160105-0000962           No
# 49  20160512-0047630           No
#
#                                             ownername  acreage  landvalue  \
# 0                                                None      NaN        NaN
# 1                                                None      NaN        NaN
# 2                                                None      NaN        NaN
# 3                                                None      NaN        NaN
# 4                                                None      NaN        NaN
# 5                                                None      NaN        NaN
# 6                                                None      NaN        NaN
# 7                                                None      NaN        NaN
# 8                                                None      NaN        NaN
# 9                                                None      NaN        NaN
# 10                                               None      NaN        NaN
# 11                                               None      NaN        NaN
# 12                                               None      NaN        NaN
# 13                                               None      NaN        NaN
# 14                                               None      NaN        NaN
# 15                                               None      NaN        NaN
# 16                                               None      NaN        NaN
# 17                                               None      NaN        NaN
# 18                                               None      NaN        NaN
# 19                                               None      NaN        NaN
# 20                                               None      NaN        NaN
# 21                                               None      NaN        NaN
# 22                                               None      NaN        NaN
# 23                                               None      NaN        NaN
# 24                                               None      NaN        NaN
# 25                    FAMILY VENTURES MANAGEMENT, LLC     0.12    11000.0
# 26                         SEAL POINT PROPERTIES, LLC     0.18    11000.0
# 27                                 KILPATRICK, AMY C.     0.26    13000.0
# 28                               KREIGH, TAMARA MINER     0.17    13000.0
# 29                                    PORT ROYAL, LLC     0.30    13000.0
# 30                          CLAYBROOKS, NATHANIEL JR.     0.21    13000.0
# 31                                AISEMBERG, PAULA A.     0.23    13000.0
# 32                                AISEMBERG, PAULA A.     0.23    13000.0
# 33  WEAVER, RYAN MICHAEL & BANKARD-WEAVER, SHELLEY A.     0.16    13000.0
# 34                     FAMILY VENTURE MANAGEMENT, LLC     0.17    13000.0
# 35                                 VRBA, ALEXANDRA E.     0.17    13000.0
# 36                                HORTON, ZAINEB JEAN     0.17    13000.0
# 37                                   HOLLAND, GREGORY     0.18    13000.0
# 38                    WARD, RICHARD W. & ELIZABETH J.     0.09    13000.0
# 39                                   DUKE BALLARD LLC     0.17    13000.0
# 40                                   DUKE BALLARD LLC     0.17    13000.0
# 41                      WOODLAND STREET PARTNERS, LLC     0.15    13000.0
# 42                            PARRELLI, EMILY & SCOTT     0.15    13000.0
# 43                            PARRELLI, EMILY & SCOTT     0.15    13000.0
# 44                   URBANGATE DEVELOPMENT GROUP, LLC     0.17    13000.0
# 45                                  WHITSETT, REBECCA     0.15    13000.0
# 46                                 EAT A BISCUIT, LLC     0.17    13000.0
# 47                     HAYWORTH, MICHAEL T. & VANESSA     0.34    13000.0
# 48                GARRAMONE, MICHELLE M. & NATALIE N.     0.17    13000.0
# 49                GARRAMONE, MICHELLE M. & NATALIE N.     0.17    13000.0
#
#     buildingvalue  totalvalue  yearbuilt  bedrooms  fullbath  halfbath  \
# 0             NaN         NaN        NaN       NaN       NaN       NaN
# 1             NaN         NaN        NaN       NaN       NaN       NaN
# 2             NaN         NaN        NaN       NaN       NaN       NaN
# 3             NaN         NaN        NaN       NaN       NaN       NaN
# 4             NaN         NaN        NaN       NaN       NaN       NaN
# 5             NaN         NaN        NaN       NaN       NaN       NaN
# 6             NaN         NaN        NaN       NaN       NaN       NaN
# 7             NaN         NaN        NaN       NaN       NaN       NaN
# 8             NaN         NaN        NaN       NaN       NaN       NaN
# 9             NaN         NaN        NaN       NaN       NaN       NaN
# 10            NaN         NaN        NaN       NaN       NaN       NaN
# 11            NaN         NaN        NaN       NaN       NaN       NaN
# 12            NaN         NaN        NaN       NaN       NaN       NaN
# 13            NaN         NaN        NaN       NaN       NaN       NaN
# 14            NaN         NaN        NaN       NaN       NaN       NaN
# 15            NaN         NaN        NaN       NaN       NaN       NaN
# 16            NaN         NaN        NaN       NaN       NaN       NaN
# 17            NaN         NaN        NaN       NaN       NaN       NaN
# 18            NaN         NaN        NaN       NaN       NaN       NaN
# 19            NaN         NaN        NaN       NaN       NaN       NaN
# 20            NaN         NaN        NaN       NaN       NaN       NaN
# 21            NaN         NaN        NaN       NaN       NaN       NaN
# 22            NaN         NaN        NaN       NaN       NaN       NaN
# 23            NaN         NaN        NaN       NaN       NaN       NaN
# 24            NaN         NaN        NaN       NaN       NaN       NaN
# 25        39500.0     50500.0     1962.0       3.0       1.0       0.0
# 26        37000.0     48000.0     1955.0       2.0       2.0       0.0
# 27       151900.0    165500.0     1930.0       4.0       1.0       1.0
# 28        48700.0     61700.0     1940.0       2.0       1.0       0.0
# 29        71200.0     84200.0     1999.0       3.0       2.0       0.0
# 30        63000.0     76000.0     1930.0       4.0       2.0       0.0
# 31        89500.0    102500.0     1984.0       3.0       2.0       0.0
# 32        89500.0    102500.0     1984.0       3.0       2.0       0.0
# 33            0.0     13000.0        NaN       NaN       NaN       NaN
# 34        45600.0     58600.0     1931.0       2.0       1.0       0.0
# 35        74300.0     87300.0     2006.0       3.0       2.0       0.0
# 36        50900.0     63900.0     1963.0       3.0       1.0       0.0
# 37        43000.0     56000.0     1965.0       2.0       2.0       0.0
# 38        50400.0     63400.0     1940.0       2.0       1.0       0.0
# 39            0.0     13000.0        NaN       NaN       NaN       NaN
# 40            0.0     13000.0        NaN       NaN       NaN       NaN
# 41            0.0     13000.0        NaN       NaN       NaN       NaN
# 42        51900.0     64900.0     1930.0       3.0       1.0       1.0
# 43        51900.0     64900.0     1930.0       3.0       1.0       1.0
# 44        71700.0     84700.0     1935.0       3.0       1.0       0.0
# 45        22700.0     35700.0     1945.0       2.0       1.0       0.0
# 46        46300.0     59300.0     1966.0       2.0       1.0       0.0
# 47       101200.0    114200.0     1950.0       6.0       1.0       0.0
# 48        50400.0     63800.0     1958.0       3.0       1.0       0.0
# 49        50400.0     63800.0     1958.0       3.0       1.0       0.0
#
#    saledateconverted propertysplitaddress propertysplitcity  \
# 0         2014-09-11     535  GARFIELD ST         NASHVILLE
# 1         2014-07-14    1708 A  7TH AVE N         NASHVILLE
# 2         2014-05-09    1708 B  7TH AVE N         NASHVILLE
# 3         2014-08-26    1710 A  7TH AVE N         NASHVILLE
# 4         2014-08-27    1710 B  7TH AVE N         NASHVILLE
# 5         2014-12-22    1802 B  7TH AVE N         NASHVILLE
# 6         2014-12-12    1802 A  7TH AVE N         NASHVILLE
# 7         2015-07-30    1711 A  6TH AVE N         NASHVILLE
# 8         2015-06-01    1711 B  6TH AVE N         NASHVILLE
# 9         2015-06-19    1712 A  7TH AVE N         NASHVILLE
# 10        2015-05-05    1712 B  7TH AVE N         NASHVILLE
# 11        2014-08-13    1721 B  7TH AVE N         NASHVILLE
# 12        2015-04-16    1721 B  7TH AVE N         NASHVILLE
# 13        2014-08-13    1721 A  7TH AVE N         NASHVILLE
# 14        2015-04-15    1721 A  7TH AVE N         NASHVILLE
# 15        2014-11-14            7TH AVE N         NASHVILLE
# 16        2015-02-12            7TH AVE N         NASHVILLE
# 17        2016-03-16      1800  7TH AVE N         NASHVILLE
# 18        2014-11-14            7TH AVE N         NASHVILLE
# 19        2015-02-12            7TH AVE N         NASHVILLE
# 20        2016-03-18     606  BUCHANAN ST         NASHVILLE
# 21        2015-12-07    1715 B  6TH AVE N         NASHVILLE
# 22        2016-05-19     1722 A7TH  AVE N         NASHVILLE
# 23        2016-09-27     1722 B7TH  AVE N         NASHVILLE
# 24        2016-09-20     1718 B6TH  AVE N         NASHVILLE
# 25        2013-09-11     1721  26TH AVE N         NASHVILLE
# 26        2015-12-16       2607  DELK AVE         NASHVILLE
# 27        2015-08-06    2511  BUCHANAN ST         NASHVILLE
# 28        2014-12-08       2514  DELK AVE         NASHVILLE
# 29        2016-09-08       2519 DELK  AVE         NASHVILLE
# 30        2015-04-27       2503  DELK AVE         NASHVILLE
# 31        2014-09-29     1725  25TH AVE N         NASHVILLE
# 32        2015-06-30     1725  25TH AVE N         NASHVILLE
# 33        2015-03-16     2505  FINLAND ST         NASHVILLE
# 34        2013-09-10       2506  OSAGE ST         NASHVILLE
# 35        2013-11-25     1738  25TH AVE N         NASHVILLE
# 36        2013-10-30     1728  25TH AVE N         NASHVILLE
# 37        2014-12-19     1717  24TH AVE N         NASHVILLE
# 38        2015-01-23      2401  SANTI AVE         NASHVILLE
# 39        2014-09-10    2309  BUCHANAN ST         NASHVILLE
# 40        2016-04-29    2309  BUCHANAN ST         NASHVILLE
# 41        2014-07-25     1748  24TH AVE N         NASHVILLE
# 42        2014-02-26     1746  24TH AVE N         NASHVILLE
# 43        2016-02-19     1746  24TH AVE N         NASHVILLE
# 44        2015-05-08     1734  24TH AVE N         NASHVILLE
# 45        2016-10-25     1730 24TH  AVE N         NASHVILLE
# 46        2015-01-15     1722  24TH AVE N         NASHVILLE
# 47        2014-10-10     1720  24TH AVE N         NASHVILLE
# 48        2016-01-04     1718  24TH AVE N         NASHVILLE
# 49        2016-05-10     1718 24TH  AVE N         NASHVILLE
#
#     ownersplitaddress ownersplitcity ownersplitstate
# 0                None           None            None
# 1                None           None            None
# 2                None           None            None
# 3                None           None            None
# 4                None           None            None
# 5                None           None            None
# 6                None           None            None
# 7                None           None            None
# 8                None           None            None
# 9                None           None            None
# 10               None           None            None
# 11               None           None            None
# 12               None           None            None
# 13               None           None            None
# 14               None           None            None
# 15               None           None            None
# 16               None           None            None
# 17               None           None            None
# 18               None           None            None
# 19               None           None            None
# 20               None           None            None
# 21               None           None            None
# 22               None           None            None
# 23               None           None            None
# 24               None           None            None
# 25   1721  26TH AVE N      NASHVILLE              TN
# 26     2607  DELK AVE      NASHVILLE              TN
# 27  2511  BUCHANAN ST      NASHVILLE              TN
# 28     2514  DELK AVE      NASHVILLE              TN
# 29     2519  DELK AVE      NASHVILLE              TN
# 30     2503  DELK AVE      NASHVILLE              TN
# 31   1725  25TH AVE N      NASHVILLE              TN
# 32   1725  25TH AVE N      NASHVILLE              TN
# 33   2505  FINLAND ST      NASHVILLE              TN
# 34     2506  OSAGE ST      NASHVILLE              TN
# 35   1738  25TH AVE N      NASHVILLE              TN
# 36   1728  25TH AVE N      NASHVILLE              TN
# 37   1717  24TH AVE N      NASHVILLE              TN
# 38    2401  SANTI AVE      NASHVILLE              TN
# 39  2309  BUCHANAN ST      NASHVILLE              TN
# 40  2309  BUCHANAN ST      NASHVILLE              TN
# 41   1748  24TH AVE N      NASHVILLE              TN
# 42   1746  24TH AVE N      NASHVILLE              TN
# 43   1746  24TH AVE N      NASHVILLE              TN
# 44   1734  24TH AVE N      NASHVILLE              TN
# 45   1730  24TH AVE N      NASHVILLE              TN
# 46   1722  24TH AVE N      NASHVILLE              TN
# 47   1720  24TH AVE N      NASHVILLE              TN
# 48   1718  24TH AVE N      NASHVILLE              TN
# 49   1718  24TH AVE N      NASHVILLE              TN
